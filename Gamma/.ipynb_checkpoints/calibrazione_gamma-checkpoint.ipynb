# %%
## Importo Librerie
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.optimize import curve_fit
import mplhep as hep
from cycler import cycler
import matplotlib.colors as colors
import multiprocessing.pool
from scipy.optimize import approx_fprime
import pandas as pd

# %%
# Impostazioni grafici
plt.style.use(hep.style.ROOT)
params = {'legend.fontsize': '10',
         'legend.loc': 'upper right',
          'legend.frameon':       'True',
          'legend.framealpha':    '0.8',      # legend patch transparency
          'legend.facecolor':     'w', # inherit from axes.facecolor; or color spec
          'legend.edgecolor':     'w',      # background patch boundary color
          'figure.figsize': (6, 4),
         'axes.labelsize': '12',
         'figure.titlesize' : '16',
         'axes.titlesize':'14',
         'xtick.labelsize':'12',
         'ytick.labelsize':'12',
         'lines.linewidth': '1',
         'text.usetex': True,
#         'axes.formatter.limits': '-5, -3',
         'axes.formatter.min_exponent': '2',
#         'axes.prop_cycle': cycler('color', 'bgrcmyk')
         'figure.subplot.left':'0.125',
         'figure.subplot.bottom':'0.125',
         'figure.subplot.right':'0.925',
         'figure.subplot.top':'0.925',
         'figure.subplot.wspace':'0.1',
         'figure.subplot.hspace':'0.1',
#         'figure.constrained_layout.use' : True
          }
plt.rcParams.update(params)
plt.rcParams['axes.prop_cycle'] = cycler(color=['b','g','r','c','m','y','k'])

# %%
## Definizione funzioni
def linear(t, b):
    return b * t

def lineare(t, a, b):
    return a + b * t

def normal(t, m, s, N = 1):
    return N/(2*np.pi)**0.5 * 1/s * np.exp(-0.5*((t-m)/s)**2)

def expon(t, a, b):
    return np.exp(b+a*t)

def picco(t, m, s, a, b, N=1):
    return normal(t, m, s, N) + expon(t, a, b)

def converter(t, a, b):
    return (t-a)/b

# %%
## Definizione parametri bins "universali"
numerobins = 10000

# %%
## Importazione dati fondo
# Analisi fondo
dataFondo = pd.read_csv('fondo2.csv')

# Lettura delle energie
fondo0 = dataFondo[" energy"][dataFondo[" ch"] == 0]
fondo1 = dataFondo[" energy"][dataFondo[" ch"] == 1]
# Presa tempo di osservazione dei due canali
tFondo0lista = dataFondo[" t"][dataFondo[" ch"] == 0]
tFondo1lista = dataFondo[" t"][dataFondo[" ch"] == 1]

tFondo0 = np.max(dataFondo[" t"][dataFondo[" ch"] == 0]) - np.min(dataFondo[" t"][dataFondo[" ch"] == 0])
tFondo1 = np.max(dataFondo[" t"][dataFondo[" ch"] == 1]) - np.min(dataFondo[" t"][dataFondo[" ch"] == 1])
# Creazione istogramma fondo ch0
f0counts, f0bins = np.histogram(fondo0, bins=numerobins)
# f0counts = f0counts/tFondo0 # Normalizzazione sul tempo d'osservazione
# Creazione istogramma fondo ch1
f1counts, f1bins = np.histogram(fondo1, bins=numerobins)
# f1counts = f1counts/tFondo1 # Normalizzazione sul tempo d'osservazione
print(tFondo0, tFondo1)
# Out:
# 1.3055100000000001e+35 3418.97

# %%
# Plot del fondo
fig, ax = plt.subplots()

plt.stairs(f0counts, f0bins, label='background')

ax.set_xlim(0,20000)

ax.set_title("Channel 0 background")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")


plt.show()

# %%
# Plot del fondo
fig, ax = plt.subplots()

plt.scatter(tFondo0lista, fondo0, s=0.1, label='Data', alpha = 0.5)

ax.set_title("Channel 0 stabilità fondo")

ax.set_ylabel("Energia [a.u.]")
ax.set_xlabel("Tempo [s]")

ax.set_ylim(0,140000)

plt.show()

# %%
# Plot del fondo
fig, ax = plt.subplots()

plt.stairs(f1counts, f1bins, label='background')

ax.set_xlim(0,5000)

ax.set_title("Channel 1 background")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()

# %%
# Plot del fondo
fig, ax = plt.subplots()

plt.scatter(tFondo1lista, fondo1, s=0.1, label='Data', alpha = 0.5)

ax.set_title("Channel 1 stabilità fondo")

ax.set_ylabel("Energia [a.u.]")
ax.set_xlabel("Tempo [s]")

plt.show()

# %%
# Lettura del set del Na
dataNa  = pd.read_csv('acqNa.csv')
dataNa.keys()
ech0 = dataNa[" energy"][dataNa[" ch"] == 0]
ech1 = dataNa[" energy"][dataNa[" ch"] == 1]

tch0 = np.max(dataNa[" t"][dataNa[" ch"] == 0]) - np.min(dataNa[" t"][dataNa[" ch"] == 0])
tch1 = np.max(dataNa[" t"][dataNa[" ch"] == 1]) - np.min(dataNa[" t"][dataNa[" ch"] == 1])

print(tch0, tch1)
# Out:
# 65.4086 65.3537

# %%
# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

ax.set_xlim(0,12000)

ax.legend()

ax.set_title("Channel 0 Na")
ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()

# %%
## Analisi ch0 del Na
# Genero lista picchi ch0
peaksch0 = []
# Genero lista incertezza picchi ch0
speaksch0 = []
# Genero lista delle sigmas ch0
sigmasch0 = []
# Genero lista valori teorici
ekeVch0 = []
# Genero lista FWHM del ch0
fwhmch0 = []

# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Na
xmin = 2000
xmax = 2600
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Na
xmin = 3300
xmax = 5000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Prendo porzione fra 2° picco e picco somma Na
xmin = 8000
xmax = 9000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1.6e-6, 6))

param = "abc"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
plt.plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', ls = "--", lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Na
xmin = 2600
xmax = 3300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
x = np.array(x)
y = np.array(y)

# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(511)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Na
xmin = 6500
xmax = 7500

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(1274.537)

param = "msabcN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)

# ----- Seleziono il picco somma del Na
xmin = 9100
xmax = 10800

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(np.abs(p[1]))

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(511+1274.537)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,12000)

ax.legend()

ax.set_title("Fit Channel 0 Na")
ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.00029086610515015315 +/- 5.755856709693755e-06
# b =  7.13924553837612 +/- 0.02002985027156187
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2925.3427644875237 +/- 0.21514008601952475
# s =  94.93832212222465 +/- 0.26028554910493346
# a =  -0.0009699186875444714 +/- 0.00013598693230076493
# b =  8.88864690503423 +/- 0.3884139072616505
# N =  3405749.7037017317 +/- 11297.422793690914
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  7062.344589180914 +/- 0.7660510959181885
# s =  149.3176871594516 +/- 0.9644905194391145
# a =  0.0002752548823643454 +/- 0.00011223687323611391
# b =  2.7649914281531105 +/- 0.7802795736477186
# c =  711462.0817251748 +/- 5871.087203007443
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  9930.159061633109 +/- 1.48936751028622
# s =  172.36017591554491 +/- 1.8541664865978245
# ...

# %%
# Genero il canvas dei grafici
fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [2,1])
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
ax[0].stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Na
xmin = 2000
xmax = 2600
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Na
xmin = 3300
xmax = 5000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Prendo porzione fra 2° picco e picco somma Na
xmin = 8000
xmax = 9000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1.6e-6, 6))

param = "abc"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
# ax[0].plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Na
xmin = 2600
xmax = 3300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
x = np.array(x)
y = np.array(y)

# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - picco(x,*p)

print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))
# ----- Seleziono il 2° picco del Na
xmin = 6500
xmax = 7500

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

print(count)

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

param = "msabcN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - picco(x,*p)
print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))

# ----- Seleziono il picco somma del Na
xmin = 9100
xmax = 10800

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - picco(x,*p)
print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))

# Limito l'area di interesse
ax[0].set_xlim(0,12000)

ax[0].legend()

ax[0].set_title("Channel 0 Na")
ax[1].set_xlabel("Energia [a.u.]")
ax[0].set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.00029086610515015315 +/- 5.755856709693755e-06
# b =  7.13924553837612 +/- 0.02002985027156187
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2925.3427644875237 +/- 0.21514008601952475
# s =  94.93832212222465 +/- 0.26028554910493346
# a =  -0.0009699186875444714 +/- 0.00013598693230076493
# b =  8.88864690503423 +/- 0.3884139072616505
# N =  3405749.7037017317 +/- 11297.422793690914
# Con un chi2 =  215.34276190245248 / 72
# 820815.4913159797
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  7062.344589180914 +/- 0.7660510959181885
# s =  149.3176871594516 +/- 0.9644905194391145
# a =  0.0002752548823643454 +/- 0.00011223687323611391
# b =  2.7649914281531105 +/- 0.7802795736477186
# c =  711462.0817251748 +/- 5871.087203007443
# Con un chi2 =  119.35629596979192 / 105
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# ...

# %%
# Genero il canvas dei grafici
fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [2,1])
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
ax[0].stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Na
xmin = 2000
xmax = 2600
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Na
xmin = 3300
xmax = 5000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Prendo porzione fra 2° picco e picco somma Na
xmin = 8000
xmax = 9000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1.6e-6, 6))

param = "abc"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
plt.plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', ls = "--", lw = 0.5)

def piccox(x, m, s, N):
    return normal(x, m, s, N) + expon(x, *backg)

# ----- Seleziono il primo picco del Na
xmin = 2600
xmax = 3300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
x = np.array(x)
y = np.array(y)

# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(piccox, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), count))

param = "msN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,3):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - piccox(x,*p)

print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), piccox(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))

ax[0].set_xlim(xmin-50,xmax+50)

ax[0].legend()

ax[0].set_title("Channel 0 Na")
ax[1].set_xlabel("Energia [a.u.]")
ax[0].set_ylabel("Counts")


plt.show()

fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [2,1])

ax[0].stairs(counts[:-1], bins, label='Data')

# ----- Seleziono il 2° picco del Na
xmin = 6500
xmax = 7500

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(piccox, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), count))

param = "msN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,3):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - piccox(x,*p)
print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), piccox(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))

ax[0].set_xlim(xmin-50,xmax+50)

ax[0].legend()

ax[0].set_title("Channel 0 Na")
ax[1].set_xlabel("Energia [a.u.]")
ax[0].set_ylabel("Counts")

ax[0].set_ylim(0, np.max(y)+50)

plt.show()

fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [2,1])

ax[0].stairs(counts[:-1], bins, label='Data')

# ----- Seleziono il picco somma del Na
xmin = 9100
xmax = 10800

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(piccox, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), count))

param = "msN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,3):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

residui = y - piccox(x,*p)
print("Con un chi2 = ", np.sum(residui**2/y), "/", len(y)-5)

# Plot dei risultati
ax[0].plot(np.arange(xmin, xmax), piccox(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0], -1)))+' s='+str(int(round(p[1], -1))), c = 'r', lw = 1)
ax[1].errorbar(x, residui, yerr = np.sqrt(y))

# Limito l'area di interesse
ax[0].set_xlim(xmin-50,xmax+50)

ax[0].set_ylim(0, np.max(y)+50)

ax[0].legend()

ax[0].set_title("Channel 0 Na")
ax[1].set_xlabel("Energia [a.u.]")
ax[0].set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.00029086610515015315 +/- 5.755856709693755e-06
# b =  7.13924553837612 +/- 0.02002985027156187
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2924.9013253464677 +/- 0.2612826489192679
# s =  93.9698645401812 +/- 0.2613070330594662
# N =  3350942.492722413 +/- 8069.25639148171
# Con un chi2 =  904.61819886019 / 72
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  7064.744498812826 +/- 1.035213281282959
# s =  143.9777410119323 +/- 1.0358909147167243
# N =  672565.319363234 +/- 4188.836129972032
# Con un chi2 =  1335.0237813765832 / 105
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  9932.839709134325 +/- 6.577382894821798
# s =  -131.34135154675587 +/- 6.577382793478619
# N =  -70835.13600250334 +/- 3071.9486444528216
# Con un chi2 =  21144.446083969113 / 181

# %%
## Prima prova di linearizzazione per calibrazione ch0
ekeV = np.array([511, 1274.537, 1785.537])

p, sp = curve_fit(lineare, peaks, ekeV)

peaks = np.array(peaks)

residui = ekeV - lineare(peaks, *p)


fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [1,0.5])
ax[0].errorbar(peaks, ekeV, xerr = speaks, fmt='o', ms = 1, label = 'Dati')

ax[0].plot(np.arange(0, 12500), lineare(np.arange(0, 12500), *p), label = "Fit lineare y = ax")

ax[1].set_xlabel("Energia aspettata [a.u.]")
ax[0].set_ylabel("Energia misurata [keV]")
ax[1].set_ylabel("Residui [keV]")

ax[0].legend()

ax[0].grid(alpha = 0.25)

ax[0].set_title("Calibrazione ch0")

speaks = np.array(speaks)

ax[1].errorbar(peaks, residui, xerr = speaks, yerr= speaks*lin[1], fmt='o', ms = 1)

ax[1].grid()


print(p, np.sqrt(np.diag(sp)))

lin = p

plt.show()

# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, lineare(bins, *lin), label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Na
xmin = 2600
xmax = 3300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(lineare(np.arange(xmin, xmax),*lin), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(lineare(p[0], *lin), -1)))+' s='+str(int(round(p[1]/lin[1], -1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Na
xmin = 6500
xmax = 7500

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

param = "msabcN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(lineare(np.arange(xmin, xmax),*lin), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(lineare(p[0], *lin), -1)))+' s='+str(int(round(p[1]/lin[1], -1))), c = 'r', lw = 1)

# ----- Seleziono il picco somma del Na
xmin = 9100
xmax = 10800

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(np.abs(p[1]))

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(lineare(np.arange(xmin, xmax),*lin), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(lineare(p[0], *lin), -1)))+' s='+str(int(round(p[1]/lin[1], -1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,lineare(12000, *lin))

ax.legend()

ax.set_title("Channel 0 Na")
ax.set_xlabel("Energia [keV]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 4
#       1 ## Prima prova di linearizzazione per calibrazione ch0
#       2 ekeV = np.array([511, 1274.537, 1785.537])
# ----> 4 p, sp = curve_fit(lineare, peaks, ekeV)
#       6 peaks = np.array(peaks)
#       8 residui = ekeV - lineare(peaks, *p)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\optimize\_minpack_py.py:1014, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1011 if ydata.size != 1 and n > ydata.size:
#    1012     raise TypeError(f"The number of func parameters={n} must not"
#    1013                     f" exceed the number of data points={ydata.size}")
# -> 1014 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
# ...

# %%
## Analisi ch1 del Na
# Genero lista picchi ch1
peaksch1 = []
# Genero lista incertezza picchi ch1
speaksch1 = []
# Genero lista delle sigmas ch0
sigmasch1 = []
# Genero lista valori teorici ch1
ekeVch1 = []
# Genero lista dei FWHM del ch1
fwhmch1 = []

# Parto con il grafico
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech1, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Na
xmin = 750
xmax = 950
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Na
xmin = 1500
xmax = 2000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# # Prendo porzione fra 2° picco e picco somma Na
# xmin = 3000
# xmax = 5000

# for i in range(len(bins)):
#     if bins[i] > xmin:
#         x.append(bins[i])
#         y.append(counts[i])
#     if bins[i] > xmax:
#         break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1e-3, 1))

param = "ab"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
# plt.plot(np.arange(500, 5000), expon(np.arange(500, 5000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Na
xmin = 1000
xmax = 1300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch1.append(p[0])
speaksch1.append(np.sqrt(np.diag(covp))[0])
sigmasch1.append(p[1])
ekeVch1.append(511)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)


param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Na
xmin = 2500
xmax = 3000

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch1.append(p[0])
speaksch1.append(np.sqrt(np.diag(covp))[0])
sigmasch1.append(p[1])
ekeVch1.append(1274.537)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,5000)

ax.legend()

ax.set_title("Channel 1 Na")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.0012747439522573512 +/- 4.647118097612741e-05
# b =  7.60927109020837 +/- 0.050208668607157274
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  1134.1840445382277 +/- 0.15656647150995234
# s =  50.7233847934644 +/- 0.20452734800191052
# a =  -0.0025241689565998803 +/- 0.00025725174332662454
# b =  8.730864868113166 +/- 0.29498722612142986
# N =  848179.8782385066 +/- 4685.532481982944
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2773.5847057695446 +/- 0.6573279855649302
# s =  77.32531732975457 +/- 0.8514367638352234
# a =  -0.0003780428979023154 +/- 0.0009707623472807431
# b =  4.361249867925219 +/- 2.577641294740278
# N =  222678.41126250784 +/- 3221.8424827951935

# %%
## Prima prova di linearizzazione del ch1
ekeV = np.array([511, 1274.537])

p, sp = curve_fit(lineare, peaks, ekeV)

peaks = np.array(peaks)

residui = ekeV - lineare(peaks, *p)


fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [1,0.5])
ax[0].errorbar(peaks, ekeV, xerr = speaks, fmt='o', ms = 1, label = 'Dati')

ax[0].plot(np.arange(0, 12500), lineare(np.arange(0, 12500), *p), label = "Fit lineare y = ax")

ax[1].set_xlabel("Energia aspettata [a.u.]")
ax[0].set_ylabel("Energia misurata [keV]")
ax[1].set_ylabel("Residui [keV]")

ax[0].legend()

ax[0].grid(alpha = 0.25)

ax[0].set_title("Calibrazione ch0")

speaks = np.array(speaks)

ax[1].errorbar(peaks, residui, xerr = speaks, yerr= speaks*lin[1], fmt='o', ms = 1)

ax[1].grid()


print(p, np.sqrt(np.diag(sp)))

lin = p

plt.show()

# Parto con il grafico
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech1, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, lineare(bins, *lin), label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Na
xmin = 1000
xmax = 1300

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(lineare(np.arange(xmin, xmax),*lin), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(lineare(p[0],*lin),-1)))+' s='+str(int(round(p[1]/lin[1],-1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Na
xmin = 2500
xmax = 3000

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(lineare(np.arange(xmin, xmax),*lin), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(lineare(p[0],*lin),-1)))+' s='+str(int(round(p[1]/lin[1],-1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,lineare(5000, *lin))

ax.legend()

ax.set_title("Channel 1 Na")

ax.set_xlabel("Energia [keV]")
ax.set_ylabel("Counts")

plt.show()

# %%
# Lettura del set del Co
dataCo  = pd.read_csv('acqCo.csv')
dataCo.keys()
ech0 = dataCo[" energy"][dataCo[" ch"] == 0]
ech1 = dataCo[" energy"][dataCo[" ch"] == 1]

tch0 = np.max(dataCo[" t"][dataCo[" ch"] == 0]) - np.min(dataCo[" t"][dataCo[" ch"] == 0])
tch1 = np.max(dataCo[" t"][dataCo[" ch"] == 1]) - np.min(dataCo[" t"][dataCo[" ch"] == 1])

print(tch0, tch1)
'''Sito di riferimento: http://www.lnhb.fr/nuclides/Co-60_tables.pdf'''
# Out:
# 303.727 303.72479899200005
# 'Sito di riferimento: http://www.lnhb.fr/nuclides/Co-60_tables.pdf'

# %%
## Analisi ch0 del Co
# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Co
xmin = 1000
xmax = 2000
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Co
xmin = 8000
xmax = 10000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1.6e-6, 6))

param = "abc"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
# plt.plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Co
xmin = 5600
xmax = 6250

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(1173.228)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Co
xmin = 6400
xmax = 7100

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(1332.492)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabcN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# ----- Seleziono il picco somma del Co
xmin = 12200
xmax = 12800

# Provo, questo picco somma si vede poco!!!!

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(np.abs(p[1]))

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(1173.228+1332.492)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)


# Limito l'area di interesse
ax.set_xlim(0,14000)

ax.legend()

ax.set_title("Channel 0 Co")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.0004532525821159113 +/- 1.8404465738908274e-05
# b =  7.535261124531055 +/- 0.02791080465854536
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  5935.535674129852 +/- 0.642579209548055
# s =  128.25168931530982 +/- 1.1425933313496404
# a =  -0.0019553500702416643 +/- 0.0004062444852369965
# b =  16.688108371960396 +/- 2.2687205266764026
# N =  1008912.6982271903 +/- 15408.19456535494
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  6710.990787782496 +/- 0.713249263588316
# s =  135.82457374035042 +/- 1.0537120235373012
# a =  0.00026115733869162074 +/- 0.0004161169446361429
# b =  2.6268390017280154 +/- 2.938478742815117
# c =  886564.5632723382 +/- 10884.552549275055
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  12501.896580222325 +/- 10.657577174538476
# s =  185.81445226721257 +/- 23.822984862963914
# ...

# %%
## Analisi ch1 del Co
# Parto con il grafico
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech1, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del Co
xmin = 500
xmax = 1000
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di Co
xmin = 3200
xmax = 3200

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
p, covp = curve_fit(expon, x, y, p0 = (-1e-3, 1))

param = "ab"
print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
for i in range(0,2):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

backg = p
# Plotto il fit del background
# plt.plot(np.arange(500, 5000), expon(np.arange(500, 5000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il primo picco del Co
xmin = 2400
xmax = 2700

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch1.append(p[0])
speaksch1.append(np.sqrt(np.diag(covp))[0])
sigmasch1.append(p[1])
ekeVch1.append(1173.228)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# ----- Seleziono il 2° picco del Co
xmin = 2800
xmax = 3050

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

x = np.array(x)
y = np.array(y)

count = np.sum(y) * wbins

p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))

# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch1.append(p[0])
speaksch1.append(np.sqrt(np.diag(covp))[0])
sigmasch1.append(p[1])
ekeVch1.append(1332.492)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,5000)

ax.legend()

ax.set_title("Channel 1 Co")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :
# a =  -0.0019565646883199935 +/- 5.030468110158583e-05
# b =  7.43605563916203 +/- 0.034643055379658144
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2550.9026034285657 +/- 1.7416150689123335
# s =  65.8258158431262 +/- 2.7510400397253414
# a =  -0.0013260623704782234 +/- 0.0006652433687967747
# b =  8.19898357551672 +/- 1.6599940190972056
# N =  104500.78253483273 +/- 7016.9569222632235
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  2895.6260571597086 +/- 5.010087665589923
# s =  75.90784055298012 +/- 6.5993599034906385
# a =  -0.005869573006822883 +/- 0.0030490291942332705
# b =  21.079975315260445 +/- 8.34549186118781
# N =  101513.13965869592 +/- 19413.39898521909

# %%
# Lettura del set del K
dataK  = pd.read_csv('acqK.csv')
dataK.keys()
ech0 = dataK[" energy"][dataK[" ch"] == 0]
ech1 = dataK[" energy"][dataK[" ch"] == 1]

tch0 = np.max(dataK[" t"][dataK[" ch"] == 0]) - np.min(dataK[" t"][dataK[" ch"] == 0])
tch1 = np.max(dataK[" t"][dataK[" ch"] == 1]) - np.min(dataK[" t"][dataK[" ch"] == 1])

print(tch0, tch1)
# Out:
# 2401.11 2401.1

# %%
fig, ax = plt.subplots()
counts, bins = np.histogram(ech1, bins=numerobins)

wbins = bins[1] - bins[0]

plt.stairs(counts, bins, label='data')

ax.legend()

ax.set_title("Channel 1 Co grezzo")

ax.set_xlim(0,15000)

plt.show()
fig, ax = plt.subplots()

plt.stairs(counts, bins, label='data')

ax.legend()

ax.set_title("Channel 0 Co grezzo 1° picco")

ax.set_xlim(400,2500)

ax.set_ylim(0,250)

plt.show()
fig, ax = plt.subplots()

plt.stairs(counts, bins, label='data')

ax.legend()

ax.set_title("Channel 0 Co grezzo 2° e 3° picco")

ax.set_ylim(0,70)

ax.set_xlim(2500,4000)

plt.show()
# fig, ax = plt.subplots()

# plt.stairs(counts, bins, label='data')

# ax.legend()

# ax.set_title("Channel 0 Co grezzo picco somma")

# ax.set_ylim(0,50)

# ax.set_xlim(12000,13000)

# plt.show()

# %%
## Analisi ch0 del K noto
# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech0, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del K
xmin = 1200
xmax = 2000
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di K
xmin = 8000
xmax = 10000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
# p, covp = curve_fit(expon, x, y, p0 = (-1.6e-10, 10))

# param = "abc"
# print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
# for i in range(0,2):
#     print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# backg = p
# # Plotto il fit del background
# plt.plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il picco del K
xmin = 7000
xmax = 7700

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), 1e-3, 5, count))
# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch0.append(p[0])
speaksch0.append(np.sqrt(np.diag(covp))[0])
sigmasch0.append(p[1])
ekeVch0.append(1460.822)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,12000)

ax.legend()

ax.set_title("Channel 0 K")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  7299.129969771059 +/- 3.076813995125641
# s =  141.1215553952765 +/- 4.740665630250466
# a =  0.0004232422060560382 +/- 0.0025972207769545796
# b =  -1.2426979422061903 +/- 20.014459171268264
# N =  94140.39473696532 +/- 5373.517640865236

# %%
## Analisi del ch1 del K noto
# Genero il canvas dei grafici
fig, ax = plt.subplots()
# Creo l'istogramma con i dati
counts, bins = np.histogram(ech1, bins=numerobins)
# Definisco larghezza bins
wbins = bins[1] - bins[0]
# Plotto l'istogramma
plt.stairs(counts, bins, label='Data')

counts = np.append(counts, [0]) # Svolgo questo passaggio per avere counts e bins della medesima lunghezza

# ----- Analisi del fondo
# Prendo una porzione prima del primo picco del K
xmin = 500
xmax = 2500
# Creo due liste vuote
x = [] # Energie
y = [] # Counts
# Ciclo sulle energie ricercate
for i in range(len(bins)):
    if bins[i] > xmin:
        # Da aggiungere
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        # Fine corsa
        break
# Prendo una porzione di fondo fra i due picchi di K
xmin = 8000
xmax = 10000

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break

# Fitto una curva esponenziale per il fondo
# p, covp = curve_fit(expon, x, y, p0 = (-1.6e-10, 10))

# param = "abc"
# print("Da fit esponenziale y=exp(a+bx) del fondo abbiamo ottenuto :")
# for i in range(0,2):
#     print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# backg = p
# # Plotto il fit del background
# plt.plot(np.arange(1850, 10000), expon(np.arange(1850, 10000), *backg), label = 'Background', c='k', lw = 0.5)

# Creo liste dove contenere le posizioni dei picchi e incertezze
peaks = []
speaks = []

# ----- Seleziono il picco del K
xmin = 3000
xmax = 3400

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
count = np.sum(y) * wbins
# Fitto la funzione del picco, considerando fondo e segnale
p, covp = curve_fit(picco, x, y, p0 = (np.mean(x),np.std(x, ddof = 1), *backg, count))
# Memorizzo i dati del picco
peaks.append(p[0])
speaks.append(p[1])

peaksch1.append(p[0])
speaksch1.append(np.sqrt(np.diag(covp))[0])
sigmasch1.append(p[1])
ekeVch1.append(1460.822)

# fwhm = 0
# first = True
# hm = 1/(2*p[1]*(2*np.pi)**0.5)
# for v in range(len(x)):
#     if first and normal(v[i])>hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = -v[i]
#         else :
#             fwhm = -v[i-1]
#         first = False
#     elif normal(v[i])< hm:
#         if abs(normal(v[i]) - hm) < abs(normal(v[i-1]) - hm):
#             fwhm = v[i]
#         else :
#             fwhm = v[i-1]
#         break
# fwhmch0.append(fwhm)

param = "msabN"
print("Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :")
for i in range(0,5):
    print(param[i], "= ", p[i], "+/-" ,np.sqrt(np.diag(covp))[i])

# Plot dei risultati
plt.plot(np.arange(xmin, xmax), picco(np.arange(xmin, xmax), *p), label = 'picco u='+str(int(round(p[0],-1)))+' s='+str(int(round(p[1],-1))), c = 'r', lw = 1)

# Limito l'area di interesse
ax.set_xlim(0,12000)

ax.legend()

ax.set_title("Channel 1 K")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

plt.show()
# Out:
# Da fit picco y= fondo(a,b,x) + N * gaussiana(m,s,x) abbiamo ottenuto :
# m =  3192.13358126823 +/- 2.900612417374925
# s =  80.50547588441768 +/- 4.316667965598232
# a =  -0.00013632159762431954 +/- 0.0004933649999964195
# b =  3.812420780355768 +/- 1.6331224626714849
# N =  22121.528891211063 +/- 1835.193767279945

# %%
## Calibrazione energie ch0
ekeVch0 = np.array(ekeVch0)
peaksch0 = np.array(peaksch0)
speaksch0 = np.array(speaksch0) 

p, sp = curve_fit(lineare, peaksch0, ekeVch0) 

residui = ekeVch0 - lineare(peaksch0, *p)


fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [1,0.5])
# ax[0].errorbar(ekeVch0, peaksch0, yerr = speaksch0, fmt='o', ms = 1, label = 'Dati')

ax[0].plot(np.arange(0, 15000), lineare(np.arange(0, 15000), *p), label = "Fit lineare y = a + bx")

ax[0].errorbar(peaksch0[3:], ekeVch0[3:], xerr = speaksch0[3:], c='orange', fmt='o', ms = 1, label = 'Dati K e Co')
ax[0].errorbar(peaksch0[:3], ekeVch0[:3], xerr = speaksch0[:3], c = 'r',fmt='o', ms = 1, label = 'Dati Na')


ax[1].set_xlabel("Energia misurata [a.u.]")
ax[0].set_ylabel("Energia aspettata [keV]")
ax[1].set_ylabel("Residui [keV]")

ax[0].legend()

ax[0].grid(alpha = 0.25)

ax[0].set_title("Calibrazione ch0")

ax[1].errorbar(peaksch0[3:], residui[3:], xerr = speaksch0[3:], yerr = p[1]*speaksch0[3:], c='orange', fmt='o', ms = 1, label = 'Dati K e Co')
ax[1].errorbar(peaksch0[:3], residui[:3], xerr = speaksch0[:3], yerr = p[1]*speaksch0[:3], c = 'r',fmt='o', ms = 1, label = 'Dati Na')

ax[1].grid()


print(p, np.sqrt(np.diag(sp)))

print((peaks)/p)
print(speaks/p)

pch0 = p

plt.show()

p, sp = curve_fit(lineare, ekeVch0[3:], peaksch0[3:])

residui = peaksch0[3:] - lineare(ekeVch0[3:], *p)


fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [1,0.5])
ax[0].errorbar(ekeVch0[3:], peaksch0[3:], yerr = speaksch0[3:], fmt='o', ms = 1, label = 'Dati')

ax[0].plot(np.arange(0, 2500), lineare(np.arange(0, 2500), *p), label = "Fit lineare y = ax")

ax[1].set_xlabel("Energia aspettata [keV]")
ax[0].set_ylabel("Energia misurata [a.u.]")
ax[1].set_ylabel("Residui [a.u.]")

ax[0].legend()

ax[0].grid(alpha = 0.25)

ax[0].set_title("Calibrazione ch0")

ax[1].errorbar(ekeVch0[3:], residui, yerr = speaksch0[3:], fmt='o', ms = 1)

ax[1].grid()


print(p, np.sqrt(np.diag(sp)))


plt.show()
# Out:
# [-55.91109006   0.19926734] [9.45484621e+01 1.18332906e-02]
# [  -57.0930307  16019.35195573]
# [ -1.43988385 404.0073887 ]
# [121.79153426   4.93805518] [4.96041845e+01 2.91730892e-02]

# %%
##### Calibrazione energie ch1
ekeVch1 = np.array(ekeVch1)
peaksch1 = np.array(peaksch1)
speaksch1 = np.array(speaksch1)## Note to self: queste incertezze non dovrebbero essere i sigma della guassiana ma gli errori dei parametri, da variare
################################## ↑↑↑↑

p, sp = curve_fit(lineare, peaksch1, ekeVch1)

residui = ekeVch1 - lineare(peaksch1, *p)

errp = np.sqrt(np.diag(sp))

fig, ax = plt.subplots(2,1, sharex = True, height_ratios = [1,0.5])
# ax[0].errorbar(ekeVch1, peaksch1, yerr = speaksch1, fmt='o', ms = 1, label = 'Dati')

ax[0].plot(np.arange(0, 5000), lineare(np.arange(0, 5000), *p), label = "Fit lineare y = a + bx")

ax[0].errorbar(peaksch1[2:], ekeVch1[2:], xerr = speaksch1[2:], c='orange', fmt='o', ms = 1, label = 'Dati K e Co')
ax[0].errorbar(peaksch1[:2], ekeVch1[:2], xerr = speaksch1[:2], c = 'r',fmt='o', ms = 1, label = 'Dati Na')

ax[0].fill_between(np.arange(0, 5000), lineare(np.arange(0, 5000), *p-errp), lineare(np.arange(0, 5000), *p+errp))


ax[1].set_xlabel("Energia misurata [a.u.]")
ax[0].set_ylabel("Energia aspettata [keV]")
ax[1].set_ylabel("Residui [keV]")

ax[0].legend()

ax[0].grid(alpha = 0.25)

ax[0].set_title("Calibrazione ch1")

ax[1].errorbar(peaksch1[2:], residui[2:], xerr = speaksch1[2:], yerr = p[1]*speaksch1[2:], c='orange', fmt='o', ms = 1, label = 'Dati K e Co')
ax[1].errorbar(peaksch1[:2], residui[:2], xerr = speaksch1[:2], yerr = p[1]*speaksch1[:2], c = 'r',fmt='o', ms = 1, label = 'Dati Na')

ax[1].grid()


print(p, np.sqrt(np.diag(sp)))

print((peaks)/p)
print(speaks/p)

pch1 = p

plt.show()
# Out:
# [-13.03024154   0.46365618] [7.5881991e+00 2.9073519e-03]
# [-244.97884949 6884.69980691]
# [ -6.17835637 173.6318422 ]

# %%
fig, ax = plt.subplots(figsize=(10,4.8))

ech0 = dataK[" energy"][dataK[" ch"] == 0]
ech1 = dataK[" energy"][dataK[" ch"] == 1]

tK0 = np.max(dataK[" t"][dataK[" ch"] == 0]) - np.min(dataK[" t"][dataK[" ch"] == 0])
tK1 = np.max(dataK[" t"][dataK[" ch"] == 1]) - np.min(dataK[" t"][dataK[" ch"] == 1])

offset = 20 # 217

f0counts, f0bins = np.histogram(fondo0, bins=7500)

counts, bins = np.histogram(ech0, bins=7500)

plt.stairs(counts[offset:] - f0counts[:-offset] * tK0/tFondo0, bins[offset:], label='K - background')
# plt.stairs(f0counts[:-offset] * tK0/tFondo0, bins[offset:], label='fondo')
# plt.stairs(counts[offset:] , bins[offset:], label='data')

xmin = 0
xmax = 12000

ax.set_xlim(xmin,xmax)
# ax.set_ylim(0,750)

ax.legend()

ax.set_title("Channel 0 Difference K - Background")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

ax.set_xlim(0,10000)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,4.8))

print(tK1/tFondo1)

f1counts, f1bins = np.histogram(fondo1, bins=7500)

counts, bins = np.histogram(ech1, bins=7500)

offset = 50 # 217

plt.stairs(counts[:-offset] - f1counts[offset:] * tK1/tFondo1, bins[offset:], label='K - background')
# plt.stairs(counts[:-offset], bins[offset:], label='K')
# plt.stairs(f1counts[offset:] * tK1/tFondo1, bins[offset:], label='background')


# plt.stairs(counts - f1counts * tK1/tFondo1, bins, label='K - background')

# plt.stairs(f1counts * tK1/tFondo1, f1bins, label='fondo')
# plt.stairs(counts, bins, label='data')

xmin = 3000
xmax = 3400

x = []
y = []

for i in range(len(bins)):
    if bins[i] > xmin:
        x.append(bins[i])
        y.append(counts[i])
    if bins[i] > xmax:
        break
# Calcolo l'area sottesa dall'istogramma per la normalizzazione della gaussiana sotto il picco
areaK = np.sum(y)

x = []
y = []

for i in range(len(f0bins)):
    if f1bins[i] > xmin:
        x.append(f1bins[i])
        y.append(f1counts[i])
    if f1bins[i] > xmax:
        break
areaFondo = np.sum(y)

print("N° dati misurati: ", areaK, " su t :", tK1, " s con rate", areaK/tK1)
print("N° dati fondo: ", areaFondo, " su t :", tFondo1, " s con rate", areaFondo/tFondo1)
print("Rate dei dati campione", areaK/tK1 - areaFondo/tFondo1)

xmin = 0
xmax = 12000

ax.set_xlim(xmin,xmax)
# ax.set_ylim(0,750)

ax.legend()

ax.set_title("Channel 1 Difference K - Background")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

ax.set_xlim(np.min(np.array(np.min(f1bins), np.min(bins))),10000)

print(np.min(f1bins)-np.min(bins))

for i in range(len(bins)):
    if f1bins[i] > bins[0]:
        print(i)
        break

plt.show()
# Out:
# 0.70228753104005
# N° dati misurati:  3315  su t : 2401.1  s con rate 1.3806172171088251
# N° dati fondo:  3253  su t : 3418.97  s con rate 0.9514561402995639
# Rate dei dati campione 0.4291610768092612
# -4324.77
# 154

# %%
fig, ax = plt.subplots(figsize=(10,4.8))

f1counts, f1bins = np.histogram(fondo1, bins=7500)

counts, bins = np.histogram(ech1, bins=7500)

# plt.stairs(counts[offset:] - f0counts[:-offset] * tK0/tFondo0, bins[offset:], label='K - background')
plt.stairs(f1counts/2103.7, f1bins, label='background')
plt.stairs(counts/2401.1, bins, label='data')

xmin = 0
xmax = 12000

ax.set_xlim(xmin,xmax)

ax.legend()

ax.set_title("Channel 1 Difference K - Background")

ax.set_xlabel("Energia [a.u.]")
ax.set_ylabel("Counts")

ax.set_xlim(2000,5000)
ax.set_ylim(0,0.2)

plt.show()

# %%
print(tFondo1)

# %%
print(tK1)

# %%
tK0 = np.max(dataK[" t"][dataK[" ch"] == 0]) - np.min(dataK[" t"][dataK[" ch"] == 0])
tK1 = np.max(dataK[" t"][dataK[" ch"] == 1]) - np.min(dataK[" t"][dataK[" ch"] == 1])


print(tK1,tK0)

print(len(dataK[" t"][dataK[" ch"] == 0])/tK0)
print(len(dataK[" t"][dataK[" ch"] == 1])/tK1)
# Out:
# 824.08 858.478
# 18.0389014045788
# 13.766867294437432
